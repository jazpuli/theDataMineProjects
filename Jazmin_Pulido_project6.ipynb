# %% [markdown]
# # Project 6 -- Jazmin Pulido

# %% [markdown]
# **TA Help:** N/A
#
# - Helped with...
#
# **Collaboration:** N/A
#
# - Helped with...

# %% [markdown]
# ## Question 1

# %%
#a. A table of the values in the Race column and how many times that each Race value occurs. 
#Also, state how many of the people in the data set have Filipino race.
library(data.table)
myDF <- fread("/anvil/projects/tdm/data/death_records/DeathRecords.csv")
table(myDF$Race)
plot(table(myDF$Age[(myDF$Race == 7)]))
# Out:
#       1       2       3       4       5       6       7      18      28      38
# 2241510  309504   18031   13297    8159     700   11074    6778    4711     623
#      48      58      68      78
#    4913     316    8737    2818
# plot without title

# %% [markdown]
# **I read the DeathRecords.csv file using fread then created a table for the race column. This showed that 7 (Philipinos) had 11074 deaths. I then plotted a table of the Philipino deaths by age which showed the outliers of 999, indicating their age wasn't given.**

# %%
#b. Plot of the table of Age values for people with Filipino race, also with Age not equal to 999.
plot(table(myDF$Age[(myDF$Race == 7) & (myDF$Age < 999)]))
# Out:
# plot without title

# %% [markdown]
# **Here I plotted the same table, but filtered again by ages less than 99 to show the distribution better.**

# %% [markdown]
# ## Question 2

# %%
#Show the number of refunds for each STORE_R value, just using indexing, in other words, without using the subset function. 
#(For instance, CENTRAL stores had 2750 refunds.)
myDF <- fread("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")
table(myDF$STORE_R[myDF$SPEND < 0])
# Out:
# CENTRAL    EAST   SOUTH    WEST
#    2750    3269    2675    3952

# %% [markdown]
# **I read the 5000_transactions.csv file using fread. Then I created a table of the store refunds (STORE_R) filtered by rows from the SPEND column that were less than 0.**

# %% [markdown]
# ## Question 3

# %%
#a. Print the most popular 6 username values, and the number of reviews that each of these 6 people wrote.
myDF <- fread("/anvil/projects/tdm/data/beer/reviews_sample.csv")
tail(sort(table(myDF$username)))
# Out:
#        jaydoc   Texasfan549         Sammy   kylehay2004 StonedTrippin
#          1489          1532          1591          1628          1630
#       acurtis
#          1646

# %% [markdown]
# **I read the reviews_sample.csv file using fread and created a table of usernames. I sorted the tables by the values instead of having it be alphabetical. I then showed the tail to show the usernames with the highest 6 values.**

# %%
#b. Find the average score of the reviews that were written by the user acurtis.
#head(myDF)
mean(myDF$score[myDF$username == 'acurtis'])
sum(myDF$score[myDF$username == 'acurtis'])/length(myDF$score[myDF$username == 'acurtis'])
# Out:
# [1] 3.655802
# [1] 3.655802

# %% [markdown]
# **After, I filtered the scores by usernames that equaled the string 'acurtis'. I used the mean function to then get the mean of the scores given by that username. I double checked by finding the sum of the filtered scores and dividing it by the number of rows which produced the same answer of ~3.655 as an average score.**

# %% [markdown]
# ## Question 4

# %%
#Give the 9 NAME values for which the TRANSACTION_DT value is missing, using indexing instead of the subset function.
library(data.table)
myDF <- fread("/anvil/projects/tdm/data/election/itcont1980.txt", quote="")
names(myDF) <- c("CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID")
#head(myDF,3)
table(myDF$NAME[is.na(myDF$TRANSACTION_DT)])
# Out:
#       CURCIO, BARBARA G SCHECK, RICHARD HERBERT          WOLFF, GARY W.
#                       1                       6                       2

# %% [markdown]
# **I read the itcont1980.txt file using fread (and assigned the given column names) and filtered out the NAME rows that had NA for the TRANSACTION_DT. I then printed a table of those NAME values that met the criteria.**

# %% [markdown]
# ## Question 5

# %%
#Give the mean of the DepDelay/anvil/projects/tdm/data/flights/subset/1990.csv") of all of the flights whose Origin airport is EWR or JFK or LGA.
myDF <- fread("/anvil/projects/tdm/data/flights/subset/1990.csv")
#head(myDF,2)
mean(myDF$DepDelay[ (!is.na(myDF$DepDelay)) & ((myDF$Origin == 'EWR') | (myDF$Origin == 'JFK') | (myDF$Origin == 'LGA'))])
# Out:
# [1] 9.400064

# %% [markdown]
# **I read the 1990.csv file using fread. Then I filtered the DepDelay values by the DePDelay's that were not NA and originated from EWR, JFK or LGA using '|'. I then took the mean of those values. This gave me the value of about 9.4 for the average DepDelay**

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
